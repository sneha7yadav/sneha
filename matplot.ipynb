# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8]
y=[10,20,30,40,50,66,89,90]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5,6,7,8,10,11,13]
y=[10,20,30,40,50,66,89,90,92,94.2,96.5]
plt.plot(x,y)
plt.show()

# %%
students=["sneha","sakshi","sanvi","saloni"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.show()

# %%
students=["sneha","sakshi","sanvi","saloni"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.show()

# %%
students=["sneha","sakshi","sanvi","saloni","shivani"]
marks=[10,20,30,44,55]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.show()

# %%
students=["sneha","sanvi","saloni","sakshi"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.plot(students,marks,color="green")
plt.show()

# %%
students=["sneha","sanvi","saloni","sakshi"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.plot(students,marks,color="pink")
plt.show()

# %%
students=["sneha","sanvi","saloni","sakshi"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.plot(students,marks,color="pink")
plt.plot(students,marks,linestyle=":")
plt.show()

# %%
students=["sneha","sanvi","saloni","sakshi"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel("students")
plt.ylabel("marks")
plt.plot(students,marks,color="red")
plt.plot(students,marks,linestyle="--")
plt.show()

# %%
students = ["Amit","Rahul","Priya","Neha"] 
marks = [75,82,91,68] 
plt.bar(students, marks)
plt.show()

# %%
students = ["Amit","Rahul","Priya","Neha"] 
marks = [75,82,91,68] 
plt.bar(students, marks)
plt.bar(students,marks,color="orange")
plt.show()

# %%
subjects = ["Math","Science","English"]  
marks = [40,35,25]  
plt.pie(marks, labels=subjects)  
plt.show()

# %%
subjects = ["Math","Science","English","EVS"]  
marks = [25,25,25,25]  
plt.pie(marks, labels=subjects,autopct="%1.1f%%")  
plt.show()

# %%
import matplotlib.pyplot as plt
marks = [45,55,67,78,88,67,78,90,45,55,67] 
plt.hist(marks,color="green") 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.array([[90,80,70],[60,49,38],[83,83,90],[20,12,13]])
plt.imshow(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=np.array([[90,80,70],[60,49,38],[83,83,90],[20,12,13],[30,40,55]])
plt.imshow(data)
plt.colorbar()
plt.show()

# %%
hours = [1,2,3,4,5] 
marks = [40,50,65,75,90] 
plt.scatter(hours, marks) 
plt.scatter(hours,marks,color="red")
plt.show()

# %%
import matplotlib.pyplot as plt
students=["sneha","sakshi","sanvi","saloni"]
marks=[10,20,30,40]
plt.plot(students,marks)
plt.title("students marks")
plt.xlabel(students)
plt.ylabel(marks)
plt.show()

# %%
import matplotlib.pyplot as plt
std=["sneha","sakshi","saloni","sanvi"]
marks=[10,20,30,40]
plt.pie(marks,labels=std,autopct="%1.1f%%")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
marks=np.array([[1,2,3],[4,5,6],[4,4,5],[45,5,6]])
plt.imshow(marks)
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
hours=[1,2,3,4,5]
marks=[40,45,50,60,70]
plt.scatter(hours,marks,color="green")
plt.show()

# %%
import matplotlib.pyplot as plt
marks=[10,20,30,40,50,60,70,80]
plt.hist(marks,color="purple")
plt.show()

# %%
import matplotlib.pyplot as plt
subjects=["english","hindi","maths","bio"]
marks=[25,25,25,25]
plt.pie(marks,labels=subjects,autopct="%1.1f%%")
plt.show()
